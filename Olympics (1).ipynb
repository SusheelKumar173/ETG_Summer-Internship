# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load Dataset

athletes = pd.read_csv("athlete_events.csv")
regions = pd.read_csv("noc_regions.csv")

# %%
athletes.head()
# Out:
#    ID                      Name  ...                             Event  Medal
# 0   1                 A Dijiang  ...       Basketball Men's Basketball    NaN
# 1   2                  A Lamusi  ...      Judo Men's Extra-Lightweight    NaN
# 2   3       Gunnar Nielsen Aaby  ...           Football Men's Football    NaN
# 3   4      Edgar Lindenau Aabye  ...       Tug-Of-War Men's Tug-Of-War   Gold
# 4   5  Christine Jacoba Aaftink  ...  Speed Skating Women's 500 metres    NaN
#
# [5 rows x 15 columns]

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
#Join the DataFrame using the pandas merge()

athletes_df = athletes.merge(regions,how='left',on = 'NOC') #Here NOC is common in both the datasets

#Print the merged dataframe

athletes_df.head()
# Out:
#    ID                      Name Sex  ...  Medal       region  notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %%
#shape  of the dataframe to know the total number of rows and columns
athletes_df.shape 
#we have added two more colums so the total number of columns is 17
# Out:
# (271116, 17)

# %%
#Column names Consistent
athletes_df.rename(columns = {'region':'Region','notes':'Notes'},inplace=True)

# %%
athletes_df.head()
# Out:
#    ID                      Name Sex  ...  Medal       Region  Notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %%
#info method to print the information about the dataframe including the index,datatypes ,columns datatypes ,null values ....
athletes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
#desc method is used for calculating statistical information about the mean , sd ,the percentage of numeric values of the dataframe and much more
athletes_df.describe() #desc() information about the numerical values
# Out:
#                   ID            Age  ...         Weight           Year
# count  271116.000000  261642.000000  ...  208241.000000  271116.000000
# mean    68248.954396      25.556898  ...      70.702393    1978.378480
# std     39022.286345       6.393561  ...      14.348020      29.877632
# min         1.000000      10.000000  ...      25.000000    1896.000000
# 25%     34643.000000      21.000000  ...      60.000000    1960.000000
# 50%     68205.000000      24.000000  ...      70.000000    1988.000000
# 75%    102097.250000      28.000000  ...      79.000000    2002.000000
# max    135571.000000      97.000000  ...     214.000000    2016.000000
#
# [8 rows x 5 columns]

# %%
#Check null values present in the columns of the dataset
nan_values = athletes_df.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
#Total number of null values 
athletes_df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
#India Details

athletes_df.query('Team == "India" ').head(5)
# Out:
#       ID                             Name Sex  ...  Medal  Region  Notes
# 505  281                   S. Abdul Hamid   M  ...    NaN   India    NaN
# 506  281                   S. Abdul Hamid   M  ...    NaN   India    NaN
# 895  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
# 896  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
# 897  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
#
# [5 rows x 17 columns]

# %%
#Japan Details

athletes_df.query('Team == "Japan" ').head(5)
# Out:
#       ID         Name Sex  ...  Medal  Region  Notes
# 625  362  Isao Ko Abe   M  ...    NaN   Japan    NaN
# 629  363   Kazumi Abe   M  ...    NaN   Japan    NaN
# 630  364    Kazuo Abe   M  ...    NaN   Japan    NaN
# 631  365    Kinya Abe   M  ...    NaN   Japan    NaN
# 632  366  Kiyoshi Abe   M  ...    NaN   Japan    NaN
#
# [5 rows x 17 columns]

# %%
#Top 10 Countries participating

top_10_countries = athletes_df.Team.value_counts().sort_values(ascending=False).head(10)
top_10_countries

# Country      #Participants
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
#Visualisation
#Plot the above table in terms of barplot
plt.figure(figsize=(12,6))
plt.title('Overall Participation by Country')
sns.barplot(x=top_10_countries.index,y=top_10_countries,palette='Set2') #Vertical barplot using seaborn library

# %%
#Age Distribution of the participants
plt.figure(figsize=(12,6))
plt.title("Age Distribution of the Athletes")
plt.xlabel('Age')
plt.ylabel('Number of Participants')
plt.hist(athletes_df.Age,bins = np.arange(10,80,2),color='orange',edgecolor = 'white');

# %%
#Different sports in Summer and Winter Olympics Games
#Winter Sports are played on snow and ice

winter_sports = athletes_df[athletes_df.Season == 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
#Summer Olympics Sports
summer_sports = athletes_df[athletes_df.Season == 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
#Male and Female Participants from 1896 to 2016 Rio Olympics

gender_counts = athletes_df.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
#Pie Chart for male and female athletes

plt.figure(figsize=(12,6))
plt.title('Gender Distribution')
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.1f%%',startangle=180,shadow=True);

# %%
#Total number of medals athletes had won

athletes_df.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
#Total number of female athletes in each olympics.

female_participants = athletes_df[(athletes_df.Sex=='F') & (athletes_df.Season=='Summer')][['Sex','Year']]
female_participants = female_participants.groupby('Year').count().reset_index()
female_participants.head()
# Out:
#    Year  Sex
# 0  1900   33
# 1  1904   16
# 2  1906   11
# 3  1908   47
# 4  1912   87

# %%
female_participants.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
womenOlympics = athletes_df[(athletes_df.Sex == 'F') & (athletes_df.Season == 'Summer')]
womenOlympics
# Out:
#             ID                                 Name  ...       Region  Notes
# 26           8   Cornelia "Cor" Aalten (-Strannood)  ...  Netherlands    NaN
# 27           8   Cornelia "Cor" Aalten (-Strannood)  ...  Netherlands    NaN
# 32          13                   Minna Maarit Aalto  ...      Finland    NaN
# 33          13                   Minna Maarit Aalto  ...      Finland    NaN
# 79          21            Ragnhild Margrethe Aamodt  ...       Norway    NaN
# ...        ...                                  ...  ...          ...    ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)  ...       Russia    NaN
# 271099  135560                    Stavroula Zygouri  ...       Greece    NaN
# 271102  135563            Olesya Nikolayevna Zykina  ...       Russia    NaN
# 271103  135563            Olesya Nikolayevna Zykina  ...       Russia    NaN
# 271110  135568               Olga Igorevna Zyuzkova  ...      Belarus    NaN
#
# [59443 rows x 17 columns]

# %%
#Count Plot
sns.set(style="darkgrid")
plt.figure(figsize=(20,10))
sns.countplot(x='Year',data=womenOlympics,palette="Spectral")
plt.title("Women Participation")
# Out:
# Text(0.5, 1.0, 'Women Participation')

# %%
#Line Graph
part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20,10))
part.loc[:,'F'].plot()
plt.title('Plot of Female Atheletes Over Time')
# Out:
# Text(0.5, 1.0, 'Plot of Female Atheletes Over Time')

# %%
#Gold Medal Athletes
goldMedals = athletes_df[(athletes_df.Medal == 'Gold')]
goldMedals.head() # Top 5 rows where medals as Gold
# Out:
#     ID                     Name Sex  ...  Medal   Region  Notes
# 3    4     Edgar Lindenau Aabye   M  ...   Gold  Denmark    NaN
# 42  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 44  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 48  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 60  20       Kjetil Andr Aamodt   M  ...   Gold   Norway    NaN
#
# [5 rows x 17 columns]

# %%
#Athletes who have secured Gold Medals whose Age is beyond 60
goldMedals['ID'][goldMedals['Age']>60].count()
# Out:
# 6

# %%
#For which Sport these Gold medals have come

sporting_event = goldMedals['Sport'][goldMedals['Age']>60]
sporting_event
# Out:
# 104003    Art Competitions
# 105199               Roque
# 190952             Archery
# 226374             Archery
# 233390            Shooting
# 261102             Archery
# Name: Sport, dtype: object

# %%
#Plot the above table result in terms of graph
plt.figure(figsize=(10,5))
plt.tight_layout()
sns.countplot(sporting_event)
plt.title('Gold Medals for Athletes Over 60 Years')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Gold Medals for Athletes Over 60 Years')

# %%
#Gold Medals from each Countries

goldMedals.Region.value_counts().reset_index(name='Medal').head(5)
# Out:
#      index  Medal
# 0      USA   2638
# 1   Russia   1599
# 2  Germany   1301
# 3       UK    678
# 4    Italy    575

# %%
#Plot the graph for the above table
totalGoldMedals = goldMedals.Region.value_counts().reset_index(name = 'Medal').head(6)
g = sns.catplot(x = "index",y="Medal",data=totalGoldMedals,
                height=5, kind="bar", palette="rocket")
g.despine(left=True)
g.set_xlabels("Top 5 Countries")
g.set_ylabels("Number of Medals")
plt.title('Gold Medals per Country')
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
#Rio Olympics for 2016

max_year = athletes_df.Year.max()
print(max_year)

team_names = athletes_df[(athletes_df.Year == max_year) & (athletes_df.Medal == 'Gold')].Team

team_names.value_counts().head(10)  #The reason here US has 137 Gold Medals because we have calculated Team Events Also (Basketball)
# Out:
# 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
# Using the above result we are going to create a barplot
sns.barplot(x=team_names.value_counts().head(20),y=team_names.value_counts().head(20).index)
plt.ylabel(None);
plt.xlabel("Country wise Medals for the year 2016")
# Out:
# Text(0.5, 0, 'Country wise Medals for the year 2016')

# %%
#Scatter Plot for visualizing the heights & weights of the male & female athletes who have won the medal(Gold,Silver,Bronze)
#first we have to filter the data only for the athletes who have won the medal
#we are not considering the null values 

not_null_medals = athletes_df[(athletes_df['Height'].notnull()) & (athletes_df['Weight'].notnull())]

# %%
plt.figure(figsize=(12,10))
axis = sns.scatterplot(x='Height',y='Weight',data = not_null_medals,hue="Sex")
plt.title("Height VS Weight of Olympic Medalist")  #Weight in kgs & #Height in cms
# Out:
# Text(0.5, 1.0, 'Height VS Weight of Olympic Medalist')
